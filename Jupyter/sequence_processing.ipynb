# %% [markdown]
# <a href="https://colab.research.google.com/github/a-mhamdi/nlp/blob/main/Jupyter/sequence_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sequence Processing Foundations
# ---

# %% [markdown]
# Our focus here is on sentiment analysis, specifically positive/negative classification, using a small, hardcoded dataset. It delves into core natural language processing concepts such as tokenization, vocabulary creation, word embedding, and handling variable sequence lengths through padding and packing. We implement and train later three distinct recurrent neural network architectures—**RNN**, **LSTM**, and **GRU**—for sentiment prediction, culminating in a comparison of their inference capabilities.

# %% [markdown]
# ## Outlines
# 1. [Dataset loading and processing](#preprocess)
# 1. [Setup of neural networks](#nn-setup)
#     - [Recurrent neural network (RNN)](#rnn)
#     - [Long short-term memory (LSTM) network](#lstm)
#     - [Gated recurrent unit (GRU)](#gru)

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence
from collections import Counter

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# General settings

# %%
BATCH_SIZE    = 2
EPOCHS        = 16
EMBED_DIM     = 32
HIDDEN_DIM    = 64
PAD_IDX       = 0

# %% [markdown]
# ## Dataset loading and processing <a name="preprocess"></a>

# %% [markdown]
# ### Raw data

# %% [markdown]
# We use a small, hardcoded dataset of 16 sentences for sentiment analysis. Each sentence is paired with a binary label: `1` for positive sentiment and `0` for negative sentiment. This dataset is intentionally small to facilitate easy understanding and execution without external downloads, focusing on the foundational concepts of sequence processing and recurrent neural networks.

# %%
SENTENCES = [
    ("i love this movie it is fantastic",          1),
    ("great film wonderful acting loved it",       1),
    ("absolutely brilliant best movie ever",       1),
    ("the story was touching and beautiful",       1),
    ("amazing performance by all the actors",      1),
    ("a masterpiece highly recommend watching",    1),
    ("enjoyable fun and very well made film",      1),
    ("outstanding cinematography and great plot",  1),
    ("this movie was terrible and boring",         0),
    ("awful waste of time hated every minute",     0),
    ("dreadful acting and a terrible story",       0),
    ("worst film i have ever seen so bad",         0),
    ("horrible movie do not watch it",             0),
    ("disappointing and dull nothing happens",     0),
    ("bad plot bad acting bad everything",         0),
    ("tedious and pointless not recommended",      0),
]

# %% [markdown]
# ### Vocabulary

# %%
def build_vocab(sentences, pad_idx=PAD_IDX):
    """Assign an integer index to each unique word."""
    counter = Counter(word for text, _ in sentences for word in text.split())
    vocab = {"<PAD>": pad_idx, "<UNK>": 1}
    for word in counter:
        vocab[word] = len(vocab)
    return vocab

# %%
vocab = build_vocab(SENTENCES)
VOCAB_SIZE = len(vocab)

# %% [markdown]
# ### Dataset and dataLoader

# %%
class SentimentDataset(Dataset):

    def __init__(self, data, vocab):
        self.samples = [
            (
                torch.tensor([vocab.get(w, 1) for w in text.split()], dtype=torch.long),
                torch.tensor(label, dtype=torch.float),
            )
            for text, label in data
        ]

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]

# %%
def collate_fn(batch):
    """
    Pad sequences in a batch to the same length.
    Returns:
        padded  — (batch, max_len)
        lengths — original lengths (needed for pack_padded_sequence)
        labels  — (batch,)
    """
    sequences, labels = zip(*batch)
    lengths = torch.tensor([len(s) for s in sequences])
    padded  = pad_sequence(sequences, batch_first=True)
    labels  = torch.stack(labels)
    return padded, lengths, labels

# %%
dataset = SentimentDataset(SENTENCES, vocab)

# %%
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)

# %% [markdown]
# ## Setup of neural networks <a name="nn-setup"></a>

# %% [markdown]
# Training function

# %%
def train(model, loader, epochs=EPOCHS, lr=5e-2):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()
    model.train()
    model.to(device)

    for epoch in range(1, epochs + 1):
        total_loss, correct, total = 0.0, 0, 0

        for text, lengths, labels in loader:
            text, lengths, labels = text.to(device), lengths, labels.to(device)
            optimizer.zero_grad()
            logits = model(text, lengths)
            loss   = criterion(logits, labels.float())
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            preds       = (torch.sigmoid(logits) >= 0.5).int()
            correct    += (preds == labels).sum().item()
            total      += labels.size(0)

        if epoch % 5 == 0:
            print(f"  Epoch {epoch:3d} | loss {total_loss/len(loader):.4f} "
                  f"| acc {correct/total*100:.1f}%")

# %% [markdown]
# Predict function for a given text input

# %%
def predict(model, sentence: str, vocab: dict) -> str:
    model.eval()
    tokens  = torch.tensor([[vocab.get(w, 1) for w in sentence.split()]]).to(device)
    lengths = torch.tensor([tokens.size(1)])

    with torch.no_grad():
        prob = torch.sigmoid(model(tokens, lengths)).item()

    return f"{'POSITIVE'} (confidence {prob:.2f})" if prob >= 0.5 else f"{'NEGATIVE'} (confidence {(1-prob):.2f})"

# %% [markdown]
# ### Recurrent neural network (RNN) <a name="rnn"></a>

# %% [markdown]
# Vanilla **RNN** struggles with long sequences due to vanishing gradients.
#
# Our designed **RNN** model contains:
#
# 1. Embedding layer (`vocab_size` → `embed_dim`)
# 1. RNN layer with basic hidden state
# 1. Fully connected layer (`hidden_dim` → `1`)

# %%
class SentimentRNN(nn.Module):

    def __init__(self, vocab_size, embed_dim, hidden_dim, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=pad_idx)
        self.rnn       = nn.RNN(embed_dim, hidden_dim, batch_first=True)
        self.fc        = nn.Linear(hidden_dim, 1)

    def forward(self, text, lengths):
        embedded = self.embedding(text)                        # (B, T, E)
        packed   = pack_padded_sequence(                       # skip PAD tokens
                       embedded, lengths, batch_first=True, enforce_sorted=False)
        _, hidden = self.rnn(packed)                           # hidden: (1, B, H)
        return self.fc(hidden.squeeze(0)).squeeze(1)           # (B,)

# %% [markdown]
# #### Instantiate and train a RNN model

# %%
model_rnn = SentimentRNN(VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM, PAD_IDX)

# %%
train(model_rnn, dataloader)
# Out:
#   Epoch   5 | loss 0.1528 | acc 93.8%
#   Epoch  10 | loss 0.0029 | acc 100.0%
#   Epoch  15 | loss 0.0011 | acc 100.0%

# %% [markdown]
# #### Inference

# %%
test_sentences = [
    "this film was absolutely wonderful",
    "i hated this boring terrible movie",
]

# %%
for sent in test_sentences:
  print(f"'{sent}' → {predict(model_rnn, sent, vocab)}")
# Out:
# 'this film was absolutely wonderful' → POSITIVE (confidence 0.99)
# 'i hated this boring terrible movie' → NEGATIVE (confidence 0.70)

# %% [markdown]
# ### Long short-term memory (LSTM) network <a name="lstm"></a>

# %% [markdown]
# **LSTM**  adds a cell state alongside the hidden state. The forget gate lets the model decide what long-range context to keep.
#
# Our designed **LSTM** model contains:
#
# 1. Embedding layer (`vocab_size` → `embed_dim`)
# 1. LSTM layer with forget, input, cell, and output gates
# 1. Fully connected layer (`hidden_dim` → `1`)

# %%
class SentimentLSTM(nn.Module):

    def __init__(self, vocab_size, embed_dim, hidden_dim, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=pad_idx)
        self.lstm      = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc        = nn.Linear(hidden_dim, 1)

    def forward(self, text, lengths):
        embedded = self.embedding(text)
        packed   = pack_padded_sequence(
                       embedded, lengths, batch_first=True, enforce_sorted=False)
        _, (hidden, _cell) = self.lstm(packed)   # we only need the hidden state
        return self.fc(hidden.squeeze(0)).squeeze(1)

# %% [markdown]
# #### Instantiate and train a LSTM model

# %%
model_lstm = SentimentLSTM(VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM, PAD_IDX)

# %%
train(model_lstm, dataloader, epochs=20)
# Out:
#   Epoch   5 | loss 0.0050 | acc 100.0%
#   Epoch  10 | loss 0.0003 | acc 100.0%
#   Epoch  15 | loss 0.0002 | acc 100.0%
#   Epoch  20 | loss 0.0001 | acc 100.0%

# %% [markdown]
# #### Inference

# %%
test_sentences = [
    "this film was absolutely wonderful",
    "i hated this boring terrible movie",
]

# %%
for sent in test_sentences:
  print(f"'{sent}' → {predict(model_lstm, sent, vocab)}")
# Out:
# 'this film was absolutely wonderful' → POSITIVE (confidence 0.99)
# 'i hated this boring terrible movie' → NEGATIVE (confidence 0.74)

# %% [markdown]
# ### Gated recurrent unit (GRU) <a name="gru"></a>

# %% [markdown]
# **GRU** merges the cell state and hidden state into one. Fewer parameters than **LSTM**, usually trains faster, often matches it in quality.
#
# Our designed **GRU** model contains:
#
# 1. Embedding layer (`vocab_size` → `embed_dim`)
# 1. GRU layer with reset gate, update gate, and hidden state
# 1. Fully connected layer (`hidden_dim` → `1`)

# %%
class SentimentGRU(nn.Module):

    def __init__(self, vocab_size, embed_dim, hidden_dim, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=pad_idx)
        self.gru       = nn.GRU(embed_dim, hidden_dim, batch_first=True)
        self.fc        = nn.Linear(hidden_dim, 1)

    def forward(self, text, lengths):
        embedded = self.embedding(text)
        packed   = pack_padded_sequence(
                       embedded, lengths, batch_first=True, enforce_sorted=False)
        _, hidden = self.gru(packed)
        return self.fc(hidden.squeeze(0)).squeeze(1)

# %% [markdown]
# #### Instantiate and train a GRU model

# %%
model_gru = SentimentGRU(VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM, PAD_IDX)

# %%
train(model_gru, dataloader)
# Out:
#   Epoch   5 | loss 0.0044 | acc 100.0%
#   Epoch  10 | loss 0.0005 | acc 100.0%
#   Epoch  15 | loss 0.0003 | acc 100.0%

# %% [markdown]
# #### Inference

# %%
test_sentences = [
    "this film was absolutely wonderful",
    "i hated this boring terrible movie",
]

# %%
for sent in test_sentences:
  print(f"'{sent}' → {predict(model_gru, sent, vocab)}")
# Out:
# 'this film was absolutely wonderful' → POSITIVE (confidence 1.00)
# 'i hated this boring terrible movie' → NEGATIVE (confidence 0.51)

# %% [markdown]
# ### Summary

# %%
test_sentences = [
    "this film was absolutely wonderful",
    "i hated this boring terrible movie",
]

# %%
models = {
    "RNN" : model_rnn,
    "LSTM": model_lstm,
    "GRU" : model_gru
}

# %%
for name, model in models.items():
    print(f"\n{'─'*45}")
    print(f"  Training {name}")
    print(f"{'─'*45}")
    train(model, dataloader, epochs=30)

    print("\n  Inference:")
    for sent in test_sentences:
        print(f"'{sent}' → {predict(model, sent, vocab)}\n")
# Out:
# ─────────────────────────────────────────────
#   Training RNN
# ─────────────────────────────────────────────
#   Epoch   5 | loss 0.0000 | acc 100.0%
#   Epoch  10 | loss 0.0000 | acc 100.0%
#   Epoch  15 | loss 0.0000 | acc 100.0%
#   Epoch  20 | loss 0.0000 | acc 100.0%
#   Epoch  25 | loss 0.0000 | acc 100.0%
#   Epoch  30 | loss 0.0000 | acc 100.0%
#
#   Inference:
# 'this film was absolutely wonderful' → POSITIVE (confidence 1.00)
#
# 'i hated this boring terrible movie' → NEGATIVE (confidence 1.00)
#
#
# ─────────────────────────────────────────────
#   Training LSTM
# ─────────────────────────────────────────────
#   Epoch   5 | loss 0.0000 | acc 100.0%
#   Epoch  10 | loss 0.0000 | acc 100.0%
#   Epoch  15 | loss 0.0000 | acc 100.0%
#   Epoch  20 | loss 0.0000 | acc 100.0%
#   Epoch  25 | loss 0.0000 | acc 100.0%
#   Epoch  30 | loss 0.0000 | acc 100.0%
#
#   Inference:
# 'this film was absolutely wonderful' → POSITIVE (confidence 0.84)
#
# ...
